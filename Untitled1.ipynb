# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = input("Enter your username:")
print("Your username is :", username)
print("First character:", username[0])
print("Last character",username[-1])
print("Second character:",username[1])
print("Second-last character:",username[-2])
# Out:
# Enter your username:Aditi
# Your username is : Aditi
# First character: A
# Last character i
# Second character: d
# Second-last character: t

# %%
name= input("Enter you name:")
first = name[0]
last = name[-1]
print("Your name starts with:",first)
print("Your name ends with:",last)
# Out:
# Enter you name:Aditi
# Your name starts with: A
# Your name ends with: i
