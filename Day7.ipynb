# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Demonstrating different characters in a string

message = "Hello! Chipra 123 😊 @ Python"

print(message)
# Out:
# Hello! Chipra 123 😊 @ Python

# %%
# Creating Strings

name = "Chipra"
city = 'Ahmedabad'
message = "I am learning Python!"

print(name)
print(city)
print(message)
# Out:
# Chipra
# Ahmedabad
# I am learning Python!
