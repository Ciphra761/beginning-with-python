# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/TypeConversionDay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name")
age=int(input("Enter your age"))
marks1=float(input("Enter marks of subject 1"))
marks2=float(input("Enter marks of subject 2"))
marks3=float(input("Enter marks of subject 3"))
total=marks1+marks2+marks3
average=total/3
fee=float(input("Enter your monthly fee"))
duration=int(input("How many months have you studied"))
totalfee=fee*duration

result =bool(age)
age_text =str(age)
print("name ", type(name))
print("age ", type(age))
print("marks1", type(marks1))
print("fee",type(fee))
print("months", type(duration))
print("totalfee", type(totalfee))
print("result", type(result))
print("age_text", type(age_text))
print(result)
a=4
b=2.4
print("a+b",a+b, type(a+b))
