# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Chipra"
age=24
city="Ahmedabad"
print(name)
print(age)
print(city)
# Out:
# Chipra
# 24
# Ahmedabad

# %%
a= int(input("Enter a number "))
b = int(input("Enter a number "))
c = a+b
print(c)
# Out:
# Enter a number 56
# Enter a number 67
# 123

# %%
num=float(input("Enter a number"))
print(type(num))
# Out:
# Enter a number67.8
# <class 'float'>

# %%
number=float("40.4")
print(type(number))
# Out:
# <class 'float'>

# %%
name="Chipra"
age=24
DayOfCode=2.0
i=2
TotalCode = 5 + 0j
LearningSuccess=True
Errors= None

print(name)
print(type(name))

print(age)
print(type(age))

print(DayOfCode)
print(type(DayOfCode))

print(TotalCode)
print(type(TotalCode))

print(LearningSuccess)
print(type(LearningSuccess))

print(Errors)
print(type(Errors))
# Out:
# Chipra
# <class 'str'>
# 24
# <class 'int'>
# 2.0
# <class 'float'>
# (5+0j)
# <class 'complex'>
# True
# <class 'bool'>
# None
# <class 'NoneType'>
