# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Indexing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word=input("Enter a word:")
position=int(input("Which position do you want to inspect?"))
print("The character is:",word[position])
# Out:
# Enter a word:Maybe
# Which position do you want to inspect?-1
# The character is: e

# %%
word=input("Enter a word:")
a=word[0]
b=word[2]
c=word[-1]
print("Your secret message is:",a+b+c)
# Out:
# Enter a word:Happy
# Your secret message is: Hpy

# %%
word=input("Enter a word")
a=word[0]
b=word[2]
c=word[-1]
d=word[-2]
print("Your requested letters are:",a,b,c,d)
# Out:
# Enter a wordMaybe
# Your requested letters are: M y e b

# %%
name=input("Enter you name:")
FirstLetter=name[0]
LastLetter=name[-1]
print("FirstLetter+LastLetter is:",FirstLetter+LastLetter)
# Out:
# Enter you name:Aditi
# FirstLetter+LastLetter is: Ai
