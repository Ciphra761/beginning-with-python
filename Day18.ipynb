# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Day18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write one program that demonstrates these five situations:

#A normal slice.
#A slice where the stop goes beyond the list's length.
#An empty slice because start == stop.
#An empty slice because you're moving in the wrong direction.
#A negative-step slice that makes the previous case work.

data = [10, 20, 30, 40, 50, 60, 70]
print(data)
print(data[0:10])
print(data[0:0])
print(data[10:0])
print(data[10:0:-1])
# Out:
# [10, 20, 30, 40, 50, 60, 70]
# [10, 20, 30, 40, 50, 60, 70]
# []
# []
# [70, 60, 50, 40, 30, 20]
