# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Day18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = (78, 85, 91, 67, 88, 95, 73)

#Write one program that does all five:

#Print the first 3 marks using slicing.
#Print the marks from index 3 to the end.
#Create a complete copy of the tuple using slicing.
#Print every second mark.
#Print the tuple in reverse.

print(marks[0:3:])
print(marks[3::])
copy = marks[:]
# { copy = marks }=> could become assignment whereas we want to use slicing.
print(copy)
print(marks[::2])
print(marks[::-1])
# Out:
# (78, 85, 91)
# (67, 88, 95, 73)
# (78, 85, 91, 67, 88, 95, 73)
# (78, 91, 88, 73)
# (73, 95, 88, 67, 91, 85, 78)
