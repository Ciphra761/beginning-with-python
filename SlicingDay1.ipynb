# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/SlicingDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username="KohinoorRare"
first_part = username[:8]
second_part = username[8:]
full_username = username[:]
print("Username:",username)
print("First part:", first_part)
print("Second part:", second_part)
print("Full username:", full_username)
# Out:
# Username: KohinoorRare
# First part: Kohinoor
# Second part: Rare
# Full username: KohinoorRare
