# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Type%20conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 25
y= float(x)
print(y)
print(type(y))
# Out:
# 25.0
# <class 'float'>

# %%
x=45.89
y=int(x)
print(y)
# Out:
# 45

# %%
age="24"
age=int(age)
print(age+5)
# Out:
# 29

# %%
number=100
text=str(number)
print("My number is "+text)
# Out:
# My number is 100

# %%
number= int(input("Enter you age"))
print("Age from five years from now:", number+5)
# Out:
# Enter you age45
# Age from five years from now: 50
