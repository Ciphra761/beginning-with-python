# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Day15_Negative_Slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = "PYTHON"
# 1. Reverse the entire string
print(word[::-1])

# 2. Reverse using a negative step
print(word[5:1:-1])

# 3. Slice using negative indexes
print(word[-1:-4:-1])

# 4. Reverse from a particular postion
print(word[4::-1])

# 5. Reverse a portion of the string
print(word[3:0:-1])
# Out:
# NOHTYP
# NOHT
# NOH
# OHTYP
# HTY

# %%
#Write a Python program that:
#Stores the product code in a variable.
#Prints the product code in reverse using negative slicing.
#Extracts the last 4 characters using negative indexes and a negative step.
#Prints the product code from index 6 backwards to the beginning.
#Prints a portion of the product code in reverse, starting at index 5 and stopping before index 1.

product = "LIPBALM2026"
p_code = product[7:11]
print(p_code[::-1])
negative_pcode = product[:-5:-1]
print(negative_pcode)
p_name = product[-5::-1]
print(p_name)
portion = product[5:1:-1]
print(portion)
# Out:
# 6202
# 6202
# MLABPIL
# LABP
