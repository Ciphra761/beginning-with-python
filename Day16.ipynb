# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/Day16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#subjects = ["Python", "DBMS", "CAO", "AI", "Networks", "OS", "Math"]

#And one program mein ye 5 things karo:
#First 3 subjects
#Index 3 se end tak
#Entire list ki copy
#Every second subject
#Entire list reverse

subjects = ["Python", "DBMS", "CAO", "AI", "Networks", "OS", "Math"]
print(subjects[0:3])
print(subjects[3::])
copy = subjects[0:-1]
print(copy)
print(subjects[::2])
print(subjects[::-1])
# Out:
# ['Python', 'DBMS', 'CAO']
# ['AI', 'Networks', 'OS', 'Math']
# ['Python', 'DBMS', 'CAO', 'AI', 'Networks', 'OS']
# ['Python', 'CAO', 'Networks', 'Math']
# ['Math', 'OS', 'Networks', 'AI', 'CAO', 'DBMS', 'Python']
