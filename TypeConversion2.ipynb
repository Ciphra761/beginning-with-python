# %% [markdown]
# <a href="https://colab.research.google.com/github/Ciphra761/beginning-with-python/blob/main/TypeConversion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Your program should:

#Ask the student's name → string
#Ask age → convert to int
#Ask marks in 3 subjects → convert each to float
#Calculate:
#Total marks
#Average marks
#Ask for the student's monthly tuition fee → convert to float
#Ask how many months → convert to int
#Calculate total fees
#Display everything neatly.
#Use str() somewhere intentionally—for example, combine a number with text using +.

name=input("What is your name")
age=int(input("How old are you"))
marks1=float(input("What is your first mark "))
marks2=float(input("What is your second mark "))
marks3=float(input("What is your third mark "))
totalm= marks1 + marks2 + marks3
averagem = totalm/3
monthlyf=float(input("Whats your monthly tution fee? "))
monthd= int(input("How many months " ))
totalfee= monthlyf * monthd
print("name",name)
print("age",age)
print("total marks",totalm)
print("average marks",averagem)
print("monthly fee",monthlyf)
print("months",monthd)
print("total fee",totalfee)
# Out:
# What is your nameAditi
# How old are you34
# What is your first mark89
# What is your second mark98
# What is your third mark65
# Whats your monthly tution fee?1000
# How many months36
# name Aditi
# age 34
# total marks 252.0
# average marks 84.0
# monthly fee 1000.0
# months 36
# total fee 36000.0
